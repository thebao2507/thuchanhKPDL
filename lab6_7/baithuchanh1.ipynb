# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
dataset =  [['Milk', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
            ['Banana', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
            ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
            ['Milk', 'Ice cream', 'Corn', 'Kidney Beans', 'Yogurt'],
            ['Corn', 'Apple', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

dataset
# Out:
# [['Milk', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Banana', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Ice cream', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Apple', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)


df
# Out:
#    Apple  Banana   Corn   Eggs  Ice cream  Kidney Beans   Milk  Onion  Yogurt
# 0   True   False  False   True      False          True   True   True    True
# 1   True    True  False   True      False          True  False   True    True
# 2   True   False  False   True      False          True   True  False   False
# 3  False   False   True  False       True          True   True  False    True
# 4   True   False   True   True       True          True  False   True   False

# %%
frequent_itemsets_60 = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets_60
# Out:
#     support                            itemsets
# 0       0.8                             (Apple)
# 1       0.8                              (Eggs)
# 2       1.0                      (Kidney Beans)
# 3       0.6                              (Milk)
# 4       0.6                             (Onion)
# 5       0.6                            (Yogurt)
# 6       0.8                       (Apple, Eggs)
# 7       0.8               (Apple, Kidney Beans)
# 8       0.6                      (Apple, Onion)
# 9       0.8                (Kidney Beans, Eggs)
# 10      0.6                       (Onion, Eggs)
# 11      0.6                (Kidney Beans, Milk)
# 12      0.6               (Kidney Beans, Onion)
# 13      0.6              (Yogurt, Kidney Beans)
# 14      0.8         (Apple, Eggs, Kidney Beans)
# 15      0.6                (Apple, Eggs, Onion)
# 16      0.6        (Apple, Onion, Kidney Beans)
# 17      0.6         (Kidney Beans, Eggs, Onion)
# 18      0.6  (Apple, Eggs, Onion, Kidney Beans)

# %%
frequent_itemsets_80 = apriori(df, min_support=0.8, use_colnames=True)
frequent_itemsets_80
# Out:
#    support                     itemsets
# 0      0.8                      (Apple)
# 1      0.8                       (Eggs)
# 2      1.0               (Kidney Beans)
# 3      0.8                (Apple, Eggs)
# 4      0.8        (Apple, Kidney Beans)
# 5      0.8         (Kidney Beans, Eggs)
# 6      0.8  (Apple, Eggs, Kidney Beans)

# %%
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent_itemsets_60, metric="confidence", min_threshold=0.85)
rules
# Out:
#                      antecedents                  consequents  \
# 0                        (Apple)                       (Eggs)
# 1                         (Eggs)                      (Apple)
# 2                        (Apple)               (Kidney Beans)
# 3                        (Onion)                      (Apple)
# 4                         (Eggs)               (Kidney Beans)
# 5                        (Onion)                       (Eggs)
# 6                         (Milk)               (Kidney Beans)
# 7                        (Onion)               (Kidney Beans)
# 8                       (Yogurt)               (Kidney Beans)
# 9                  (Apple, Eggs)               (Kidney Beans)
# 10         (Apple, Kidney Beans)                       (Eggs)
# 11          (Kidney Beans, Eggs)                      (Apple)
# 12                       (Apple)         (Kidney Beans, Eggs)
# 13                        (Eggs)        (Apple, Kidney Beans)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent_itemsets_80, metric="confidence", min_threshold=0.85)
rules
# Out:
#              antecedents            consequents  antecedent support  \
# 0                (Apple)                 (Eggs)                 0.8
# 1                 (Eggs)                (Apple)                 0.8
# 2                (Apple)         (Kidney Beans)                 0.8
# 3                 (Eggs)         (Kidney Beans)                 0.8
# 4          (Apple, Eggs)         (Kidney Beans)                 0.8
# 5  (Apple, Kidney Beans)                 (Eggs)                 0.8
# 6   (Kidney Beans, Eggs)                (Apple)                 0.8
# 7                (Apple)   (Kidney Beans, Eggs)                 0.8
# 8                 (Eggs)  (Apple, Kidney Beans)                 0.8
#
#    consequent support  support  confidence  lift  leverage  conviction
# 0                 0.8      0.8         1.0  1.25      0.16         inf
# 1                 0.8      0.8         1.0  1.25      0.16         inf
# 2                 1.0      0.8         1.0  1.00      0.00         inf
# ...
